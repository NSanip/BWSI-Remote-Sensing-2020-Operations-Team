# %%
import numpy as np
import pandas as pd
import geopandas as gpd
from matplotlib import pyplot as plt
import cv2
import os
import sys
import glob
import urllib.request
import json

# %%
file = pd.read_csv("http://ladi.s3-us-west-2.amazonaws.com/Labels/ladi_images_metadata.csv")
file
# Out:
#                                             uuid            timestamp  \
# 0       a13fb353cca1f5e8060f95c80deb0c49e9a21f91  2016-01-16 07:34:55
# 1       03e5da2bc5e32cd7d58a164eefce499e2f14e06f  2014-06-24 13:09:20
# 2       c97e83122e14ec5fa5cfa6e2c911e066d8a07f7c  2014-06-24 11:06:27
# 3       c534eb158948b63508eab34a667bf495e129f455  2014-06-24 11:20:03
# 4       1c702459e21e5a7e7fec5eefaab42f5e5124113a  2014-06-24 11:21:07
# ...                                          ...                  ...
# 580746  95fabbdbbb494beab517b5fea25a4e430d8fbcef  2020-01-27 12:01:31
# 580747  4b590e5634dae396db6c838844d7670e5ef9e7f6  2020-01-27 12:00:25
# 580748  bb7f86f1e9ab1a1ab3ea9e13cda998ab6e1bbb6d  2020-01-27 12:02:25
# 580749  c9e5c19cb7cccf181d11b707f1a47b80341710b6  2020-01-27 12:00:45
# 580750  a52da08206e51e3cd3b2cd0b42a3bb7e9623e92c  2020-01-27 12:00:39
#
#           gps_lat    gps_lon  gps_alt  file_size   width  height  \
# 0       29.623744 -95.652153     26.0  3497125.0  4608.0  3456.0
# 1       32.386939 -86.344467    489.0  3518243.0  4608.0  3456.0
# 2             NaN        NaN      NaN  8006650.0  6000.0  4000.0
# 3             NaN        NaN      NaN  8821238.0  6000.0  4000.0
# 4       32.371777 -86.345887    459.0  8385536.0  6000.0  4000.0
# ...           ...        ...      ...        ...     ...     ...
# 580746  18.002950 -66.896370    101.8  3413576.0  4000.0  3000.0
# 580747  18.003440 -66.896118    101.8  3307879.0  4000.0  3000.0
# 580748  18.003280 -66.895955    101.8  3989427.0  4000.0  3000.0
# 580749  18.003355 -66.896256    101.8  3722615.0  4000.0  3000.0
# 580750  18.003379 -66.896208    101.8  3696682.0  4000.0  3000.0
#
#                                                   s3_path  \
# 0       s3://ladi/Images/FEMA_CAP/1012/20118/VIRB0002_...
# 1       s3://ladi/Images/FEMA_CAP/1012/20118/VIRB0820_...
# 2       s3://ladi/Images/FEMA_CAP/1012/20118/_DSC0015_...
# 3       s3://ladi/Images/FEMA_CAP/1012/20118/_DSC0123_...
# 4       s3://ladi/Images/FEMA_CAP/1012/20118/_DSC0126_...
# ...                                                   ...
# 580746  s3://ladi/Images/FEMA_CAP/9173/616637/2020_012...
# 580747  s3://ladi/Images/FEMA_CAP/9173/616637/2020_012...
# 580748  s3://ladi/Images/FEMA_CAP/9173/616637/2020_012...
# 580749  s3://ladi/Images/FEMA_CAP/9173/616637/2020_012...
# 580750  s3://ladi/Images/FEMA_CAP/9173/616637/2020_012...
#
#                                                       url
# 0       https://ladi.s3-us-west-2.amazonaws.com/Images...
# 1       https://ladi.s3-us-west-2.amazonaws.com/Images...
# 2       https://ladi.s3-us-west-2.amazonaws.com/Images...
# 3       https://ladi.s3-us-west-2.amazonaws.com/Images...
# 4       https://ladi.s3-us-west-2.amazonaws.com/Images...
# ...                                                   ...
# 580746  https://ladi.s3-us-west-2.amazonaws.com/Images...
# 580747  https://ladi.s3-us-west-2.amazonaws.com/Images...
# 580748  https://ladi.s3-us-west-2.amazonaws.com/Images...
# 580749  https://ladi.s3-us-west-2.amazonaws.com/Images...
# 580750  https://ladi.s3-us-west-2.amazonaws.com/Images...
#
# [580751 rows x 10 columns]

# %%
file = pd.read_csv("http://ladi.s3-us-west-2.amazonaws.com/Labels/ladi_images_metadata.csv")
maas = file.loc[(file['gps_lat'] < 42.368520) & (file['gps_lat'] > 41.791453) & (file['gps_lon'] > -73.255974) &( file['gps_lon'] < - 69.998533)] 
maas
maas.to_csv('massachusetts.csv')

# %%
for idx, url in enumerate(maas['url']):
    if idx<50:
        urllib.request.urlretrieve(url, 'mass/images/{}.jpg'.format(idx))

# %%
# Take initial guess of intrinsic parameters through metadata
# !opensfm extract_metadata mass/

# Detect features points 
# !opensfm detect_features mass/

# Match feature points across images
# !opensfm match_features mass/

# This creates "tracks" for the features. That is to say, if a feature in image 1 is matched with one in image 2,
# and in turn that one is matched with one in image 3, then it links the matches between 1 and 3. In this case, 
# it does not matter since we only have two images
# !opensfm create_tracks mass/

# Calculates the essential matrix, the camera pose and the reconstructed feature points
# !opensfm reconstruct mass/

# For visualization using Open3D
# !opensfm export_ply mass/
# Out:
# 2020-07-28 21:23:28,029 INFO: Extracting EXIF for 9.jpg
# 2020-07-28 21:23:28,178 INFO: Extracting EXIF for 26.jpg
# 2020-07-28 21:23:28,259 INFO: Extracting EXIF for 14.jpg
# 2020-07-28 21:23:28,388 INFO: Extracting EXIF for 16.jpg
# 2020-07-28 21:23:28,517 INFO: Extracting EXIF for 43.jpg
# 2020-07-28 21:23:28,587 INFO: Extracting EXIF for 30.jpg
# 2020-07-28 21:23:28,665 INFO: Extracting EXIF for 23.jpg
# 2020-07-28 21:23:28,752 INFO: Extracting EXIF for 12.jpg
# 2020-07-28 21:23:28,881 INFO: Extracting EXIF for 10.jpg
# 2020-07-28 21:23:29,010 INFO: Extracting EXIF for 25.jpg
# 2020-07-28 21:23:29,089 INFO: Extracting EXIF for 1.jpg
# 2020-07-28 21:23:29,218 INFO: Extracting EXIF for 24.jpg
# 2020-07-28 21:23:29,297 INFO: Extracting EXIF for 13.jpg
# 2020-07-28 21:23:29,417 INFO: Extracting EXIF for 4.jpg
# 2020-07-28 21:23:29,542 INFO: Extracting EXIF for 22.jpg
# 2020-07-28 21:23:29,622 INFO: Extracting EXIF for 21.jpg
# 2020-07-28 21:23:29,695 INFO: Extracting EXIF for 35.jpg
# 2020-07-28 21:23:29,773 INFO: Extracting EXIF for 37.jpg
# 2020-07-28 21:23:29,848 INFO: Extracting EXIF for 46.jpg
# 2020-07-28 21:23:29,922 INFO: Extracting EXIF for 32.jpg
# 2020-07-28 21:23:30,000 INFO: Extracting EXIF for 27.jpg
# 2020-07-28 21:23:30,077 INFO: Extracting EXIF for 42.jpg
# 2020-07-28 21:23:30,147 INFO: Extracting EXIF for 7.jpg
# 2020-07-28 21:23:30,275 INFO: Extracting EXIF for 2.jpg
# 2020-07-28 21:23:30,405 INFO: Extracting EXIF for 38.jpg
# 2020-07-28 21:23:30,481 INFO: Extracting EXIF for 0.jpg
# 2020-07-28 21:23:30,606 INFO: Extracting EXIF for 18.jpg
# 2020-07-28 21:23:44,202 INFO: Extracting ROOT_HAHOG features for image 30.jpg
# 2020-07-28 21:23:45,819 DEBUG: Found 4916 points in 1.1103167533874512s
# 2020-07-28 21:23:45,820 DEBUG: No segmentation for 30.jpg, no features masked.
# 2020-07-28 21:23:45,856 INFO: Extracting ROOT_HAHOG features for image 23.jpg
# 2020-07-28 21:23:47,475 DEBUG: Found 4880 points in 1.1080753803253174s
# 2020-07-28 21:23:47,476 DEBUG: No segmentation for 23.jpg, no features masked.
# 2020-07-28 21:23:47,512 INFO: Extracting ROOT_HAHOG features for image 12.jpg
# 2020-07-28 21:23:49,546 DEBUG: Found 4880 points in 1.1159608364105225s
# 2020-07-28 21:23:49,547 DEBUG: No segmentation for 12.jpg, no features masked.
# 2020-07-28 21:23:49,585 INFO: Extracting ROOT_HAHOG features for image 10.jpg
# 2020-07-28 21:23:51,622 DEBUG: Found 4870 points in 1.12614107131958s
# 2020-07-28 21:23:51,623 DEBUG: No segmentation for 10.jpg, no features masked.
# 2020-07-28 21:23:51,659 INFO: Extracting ROOT_HAHOG features for image 25.jpg
# 2020-07-28 21:23:53,276 DEBUG: Found 4853 points in 1.1104388236999512s
# 2020-07-28 21:23:53,277 DEBUG: No segmentation for 25.jpg, no features masked.
# 2020-07-28 21:23:53,314 INFO: Extracting ROOT_HAHOG features for image 1.jpg
# 2020-07-28 21:23:55,279 DEBUG: Found 4829 points in 1.1000497341156006s
# 2020-07-28 21:23:55,280 DEBUG: No segmentation for 1.jpg, no features masked.
# 2020-07-28 21:23:55,315 INFO: Extracting ROOT_HAHOG features for image 24.jpg
# 2020-07-28 21:23:56,904 DEBUG: Found 4882 points in 1.0862832069396973s
# 2020-07-28 21:23:56,905 DEBUG: No segmentation for 24.jpg, no features masked.
# 2020-07-28 21:23:56,942 INFO: Extracting ROOT_HAHOG features for image 13.jpg
# 2020-07-28 21:23:58,900 DEBUG: Found 4808 points in 1.101372480392456s
# 2020-07-28 21:23:58,902 DEBUG: No segmentation for 13.jpg, no features masked.
# 2020-07-28 21:23:58,941 INFO: Extracting ROOT_HAHOG features for image 4.jpg
# 2020-07-28 21:24:00,917 DEBUG: Found 4875 points in 1.1170692443847656s
# 2020-07-28 21:24:00,918 DEBUG: No segmentation for 4.jpg, no features masked.
# 2020-07-28 21:24:00,954 INFO: Extracting ROOT_HAHOG features for image 22.jpg
# 2020-07-28 21:24:02,587 DEBUG: Found 4883 points in 1.1167430877685547s
# 2020-07-28 21:24:02,588 DEBUG: No segmentation for 22.jpg, no features masked.
# 2020-07-28 21:24:02,624 INFO: Extracting ROOT_HAHOG features for image 21.jpg
# 2020-07-28 21:24:04,207 DEBUG: Found 4661 points in 1.087350845336914s
# 2020-07-28 21:24:04,208 DEBUG: No segmentation for 21.jpg, no features masked.
# 2020-07-28 21:24:04,244 INFO: Extracting ROOT_HAHOG features for image 35.jpg
# 2020-07-28 21:24:05,834 DEBUG: Found 4799 points in 1.0899181365966797s
# 2020-07-28 21:24:05,835 DEBUG: No segmentation for 35.jpg, no features masked.
# 2020-07-28 21:24:05,871 INFO: Extracting ROOT_HAHOG features for image 37.jpg
# 2020-07-28 21:24:07,458 DEBUG: Found 4839 points in 1.093595027923584s
# 2020-07-28 21:24:07,459 DEBUG: No segmentation for 37.jpg, no features masked.
# 2020-07-28 21:24:07,494 INFO: Extracting ROOT_HAHOG features for image 46.jpg
# 2020-07-28 21:24:09,116 DEBUG: Found 4858 points in 1.1211071014404297s
# 2020-07-28 21:24:09,116 DEBUG: No segmentation for 46.jpg, no features masked.
# 2020-07-28 21:24:09,153 INFO: Extracting ROOT_HAHOG features for image 32.jpg
# 2020-07-28 21:24:10,753 DEBUG: Found 4832 points in 1.097334623336792s
# 2020-07-28 21:24:10,754 DEBUG: No segmentation for 32.jpg, no features masked.
# 2020-07-28 21:24:10,790 INFO: Extracting ROOT_HAHOG features for image 27.jpg
# 2020-07-28 21:24:12,400 DEBUG: Found 4849 points in 1.0970900058746338s
# 2020-07-28 21:24:12,401 DEBUG: No segmentation for 27.jpg, no features masked.
# 2020-07-28 21:24:12,437 INFO: Extracting ROOT_HAHOG features for image 42.jpg
# 2020-07-28 21:24:14,015 DEBUG: Found 4853 points in 1.0929014682769775s
# 2020-07-28 21:24:14,016 DEBUG: No segmentation for 42.jpg, no features masked.
# 2020-07-28 21:24:14,054 INFO: Extracting ROOT_HAHOG features for image 7.jpg
# 2020-07-28 21:24:16,011 DEBUG: Found 5061 points in 1.1011390686035156s
# 2020-07-28 21:24:16,012 DEBUG: No segmentation for 7.jpg, no features masked.
# 2020-07-28 21:24:16,049 INFO: Extracting ROOT_HAHOG features for image 2.jpg
# 2020-07-28 21:24:17,998 DEBUG: Found 4807 points in 1.098954200744629s
# 2020-07-28 21:24:17,999 DEBUG: No segmentation for 2.jpg, no features masked.
# 2020-07-28 21:24:18,037 INFO: Extracting ROOT_HAHOG features for image 38.jpg
# 2020-07-28 21:24:19,626 DEBUG: Found 4901 points in 1.0955417156219482s
# 2020-07-28 21:24:19,627 DEBUG: No segmentation for 38.jpg, no features masked.
# 2020-07-28 21:24:19,662 INFO: Extracting ROOT_HAHOG features for image 0.jpg
# 2020-07-28 21:24:21,626 DEBUG: Found 4779 points in 1.1110146045684814s
# 2020-07-28 21:24:21,627 DEBUG: No segmentation for 0.jpg, no features masked.
# 2020-07-28 21:24:21,662 INFO: Extracting ROOT_HAHOG features for image 18.jpg
# 2020-07-28 21:24:23,261 DEBUG: Found 4708 points in 1.0891788005828857s
# 2020-07-28 21:24:23,261 DEBUG: No segmentation for 18.jpg, no features masked.
# 2020-07-28 21:24:23,297 INFO: Extracting ROOT_HAHOG features for image 41.jpg
# 2020-07-28 21:24:24,871 DEBUG: Found 4892 points in 1.078458547592163s
# 2020-07-28 21:24:24,872 DEBUG: No segmentation for 41.jpg, no features masked.
# 2020-07-28 21:24:24,910 INFO: Extracting ROOT_HAHOG features for image 6.jpg
# 2020-07-28 21:24:26,856 DEBUG: Found 4966 points in 1.0901780128479004s
# 2020-07-28 21:24:26,857 DEBUG: No segmentation for 6.jpg, no features masked.
# 2020-07-28 21:24:26,894 INFO: Extracting ROOT_HAHOG features for image 19.jpg
# 2020-07-28 21:24:28,469 DEBUG: Found 4646 points in 1.0798590183258057s
# 2020-07-28 21:24:28,470 DEBUG: No segmentation for 19.jpg, no features masked.
# 2020-07-28 21:24:28,505 INFO: Extracting ROOT_HAHOG features for image 15.jpg
# 2020-07-28 21:24:30,470 DEBUG: Found 4828 points in 1.0821921825408936s
# 2020-07-28 21:24:30,471 DEBUG: No segmentation for 15.jpg, no features masked.
# 2020-07-28 21:24:30,507 INFO: Extracting ROOT_HAHOG features for image 11.jpg
# 2020-07-28 21:24:32,487 DEBUG: Found 4877 points in 1.0979077816009521s
# 2020-07-28 21:24:32,488 DEBUG: No segmentation for 11.jpg, no features masked.
# 2020-07-28 21:24:32,523 INFO: Extracting ROOT_HAHOG features for image 48.jpg
# 2020-07-28 21:24:34,128 DEBUG: Found 4934 points in 1.1088943481445312s
# 2020-07-28 21:24:34,129 DEBUG: No segmentation for 48.jpg, no features masked.
# 2020-07-28 21:24:34,165 INFO: Extracting ROOT_HAHOG features for image 33.jpg
# 2020-07-28 21:24:35,757 DEBUG: Found 4786 points in 1.089261531829834s
# 2020-07-28 21:24:35,758 DEBUG: No segmentation for 33.jpg, no features masked.
# 2020-07-28 21:24:35,794 INFO: Extracting ROOT_HAHOG features for image 49.jpg
# 2020-07-28 21:24:37,381 DEBUG: Found 4878 points in 1.0979723930358887s
# 2020-07-28 21:24:37,382 DEBUG: No segmentation for 49.jpg, no features masked.
# 2020-07-28 21:24:37,418 INFO: Extracting ROOT_HAHOG features for image 40.jpg
# 2020-07-28 21:24:39,013 DEBUG: Found 4844 points in 1.0988502502441406s
# 2020-07-28 21:24:39,014 DEBUG: No segmentation for 40.jpg, no features masked.
# 2020-07-28 21:24:39,049 INFO: Extracting ROOT_HAHOG features for image 31.jpg
# 2020-07-28 21:24:40,704 DEBUG: Found 4847 points in 1.1572134494781494s
# 2020-07-28 21:24:40,705 DEBUG: No segmentation for 31.jpg, no features masked.
# 2020-07-28 21:24:40,742 INFO: Extracting ROOT_HAHOG features for image 44.jpg
# 2020-07-28 21:24:42,358 DEBUG: Found 4778 points in 1.1061129570007324s
# 2020-07-28 21:24:42,359 DEBUG: No segmentation for 44.jpg, no features masked.
# 2020-07-28 21:24:42,395 INFO: Extracting ROOT_HAHOG features for image 36.jpg
# 2020-07-28 21:24:43,976 DEBUG: Found 4789 points in 1.0890922546386719s
# 2020-07-28 21:24:43,977 DEBUG: No segmentation for 36.jpg, no features masked.
# 2020-07-28 21:24:44,012 INFO: Extracting ROOT_HAHOG features for image 3.jpg
# 2020-07-28 21:24:45,962 DEBUG: Found 4845 points in 1.0992803573608398s
# 2020-07-28 21:24:45,963 DEBUG: No segmentation for 3.jpg, no features masked.
# 2020-07-28 21:24:45,998 INFO: Extracting ROOT_HAHOG features for image 34.jpg
# 2020-07-28 21:24:47,585 DEBUG: Found 4768 points in 1.0865650177001953s
# 2020-07-28 21:24:47,586 DEBUG: No segmentation for 34.jpg, no features masked.
# 2020-07-28 21:24:47,623 INFO: Extracting ROOT_HAHOG features for image 28.jpg
# 2020-07-28 21:24:49,243 DEBUG: Found 4844 points in 1.1211650371551514s
# 2020-07-28 21:24:49,244 DEBUG: No segmentation for 28.jpg, no features masked.
# 2020-07-28 21:24:49,280 INFO: Extracting ROOT_HAHOG features for image 39.jpg
# 2020-07-28 21:24:50,893 DEBUG: Found 4923 points in 1.1146113872528076s
# 2020-07-28 21:24:50,894 DEBUG: No segmentation for 39.jpg, no features masked.
# 2020-07-28 21:24:50,931 INFO: Extracting ROOT_HAHOG features for image 29.jpg
# 2020-07-28 21:24:52,560 DEBUG: Found 4888 points in 1.105839490890503s
# 2020-07-28 21:24:52,561 DEBUG: No segmentation for 29.jpg, no features masked.
# 2020-07-28 21:24:52,597 INFO: Extracting ROOT_HAHOG features for image 8.jpg
# 2020-07-28 21:24:54,552 DEBUG: Found 4809 points in 1.099872350692749s
# 2020-07-28 21:24:54,553 DEBUG: No segmentation for 8.jpg, no features masked.
# 2020-07-28 21:24:54,589 INFO: Extracting ROOT_HAHOG features for image 20.jpg
# 2020-07-28 21:24:56,158 DEBUG: Found 4610 points in 1.0768907070159912s
# 2020-07-28 21:24:56,159 DEBUG: No segmentation for 20.jpg, no features masked.
# 2020-07-28 21:24:56,195 INFO: Extracting ROOT_HAHOG features for image 45.jpg
# 2020-07-28 21:24:57,805 DEBUG: Found 4791 points in 1.1172490119934082s
# 2020-07-28 21:24:57,806 DEBUG: No segmentation for 45.jpg, no features masked.
# 2020-07-28 21:24:57,843 INFO: Extracting ROOT_HAHOG features for image 5.jpg
# 2020-07-28 21:24:59,830 DEBUG: Found 4938 points in 1.1246089935302734s
# 2020-07-28 21:24:59,831 DEBUG: No segmentation for 5.jpg, no features masked.
# 2020-07-28 21:24:59,867 INFO: Extracting ROOT_HAHOG features for image 17.jpg
# 2020-07-28 21:25:01,473 DEBUG: Found 4663 points in 1.1184353828430176s
# 2020-07-28 21:25:01,474 DEBUG: No segmentation for 17.jpg, no features masked.
# 2020-07-28 21:25:01,510 INFO: Extracting ROOT_HAHOG features for image 47.jpg
# 2020-07-28 21:25:03,097 DEBUG: Found 4832 points in 1.093902826309204s
# 2020-07-28 21:25:03,098 DEBUG: No segmentation for 47.jpg, no features masked.
# 2020-07-28 21:25:05,317 INFO: Matching 60 image pairs
# 2020-07-28 21:25:05,325 INFO: Computing pair matching with 1 processes
# 2020-07-28 21:25:05,349 DEBUG: No segmentation for 9.jpg, no features masked.
# 2020-07-28 21:25:05,351 DEBUG: No segmentation for 8.jpg, no features masked.
# 2020-07-28 21:25:05,875 DEBUG: Matching 9.jpg and 8.jpg.  Matcher: FLANN (symmetric) T-desc: 0.524 T-robust: 0.001 T-total: 0.525 Matches: 176 Robust: 172 Success: True
# 2020-07-28 21:25:09,380 DEBUG: Matching 19.jpg and 21.jpg.  Matcher: FLANN (symmetric) T-desc: 0.318 T-robust: 0.001 T-total: 0.320 Matches: 445 Robust: 423 Success: True
# 2020-07-28 21:25:09,390 DEBUG: No segmentation for 20.jpg, no features masked.
# 2020-07-28 21:25:09,721 DEBUG: Matching 19.jpg and 20.jpg.  Matcher: FLANN (symmetric) T-desc: 0.327 T-robust: 0.003 T-total: 0.330 Matches: 1223 Robust: 1193 Success: True
# 2020-07-28 21:25:09,721 DEBUG: Image 19.jpg matches: 2 out of 2
# 2020-07-28 21:25:09,739 DEBUG: No segmentation for 2.jpg, no features masked.
# 2020-07-28 21:25:09,741 DEBUG: No segmentation for 0.jpg, no features masked.
# 2020-07-28 21:25:10,247 DEBUG: Matching 2.jpg and 0.jpg.  Matcher: FLANN (symmetric) T-desc: 0.508 Matches: FAILED
# 2020-07-28 21:25:10,257 DEBUG: No segmentation for 1.jpg, no features masked.
# 2020-07-28 21:25:10,599 DEBUG: Matching 2.jpg and 1.jpg.  Matcher: FLANN (symmetric) T-desc: 0.341 T-robust: 0.001 T-total: 0.343 Matches: 500 Robust: 461 Success: True
# 2020-07-28 21:25:10,599 DEBUG: Image 2.jpg matches: 1 out of 2
# 2020-07-28 21:25:10,617 DEBUG: No segmentation for 23.jpg, no features masked.
# 2020-07-28 21:25:10,618 DEBUG: No segmentation for 24.jpg, no features masked.
# 2020-07-28 21:25:11,169 DEBUG: Matching 23.jpg and 24.jpg.  Matcher: FLANN (symmetric) T-desc: 0.546 T-robust: 0.004 T-total: 0.550 Matches: 1425 Robust: 1414 Success: True
# 2020-07-28 21:25:11,179 DEBUG: No segmentation for 22.jpg, no features masked.
# 2020-07-28 21:25:11,531 DEBUG: Matching 23.jpg and 22.jpg.  Matcher: FLANN (symmetric) T-desc: 0.348 T-robust: 0.003 T-total: 0.351 Matches: 1226 Robust: 1207 Success: True
# 2020-07-28 21:25:11,531 DEBUG: Image 23.jpg matches: 2 out of 2
# 2020-07-28 21:25:11,549 DEBUG: No segmentation for 28.jpg, no features masked.
# 2020-07-28 21:25:11,550 DEBUG: No segmentation for 29.jpg, no features masked.
# 2020-07-28 21:25:12,084 DEBUG: Matching 28.jpg and 29.jpg.  Matcher: FLANN (symmetric) T-desc: 0.529 T-robust: 0.004 T-total: 0.533 Matches: 1599 Robust: 1568 Success: True
# 2020-07-28 21:25:12,095 DEBUG: No segmentation for 30.jpg, no features masked.
# 2020-07-28 21:25:12,442 DEBUG: Matching 28.jpg and 30.jpg.  Matcher: FLANN (symmetric) T-desc: 0.345 T-robust: 0.002 T-total: 0.347 Matches: 732 Robust: 708 Success: True
# 2020-07-28 21:25:12,442 DEBUG: Image 28.jpg matches: 2 out of 2
# 2020-07-28 21:25:12,460 DEBUG: No segmentation for 31.jpg, no features masked.
# 2020-07-28 21:25:12,462 DEBUG: No segmentation for 33.jpg, no features masked.
# 2020-07-28 21:25:33,222 DEBUG: Ceres Solver Report: Iterations: 1, Initial cost: 5.995806e+05, Final cost: 5.995806e+05, Termination: CONVERGENCE
# 2020-07-28 21:25:33,859 DEBUG: Ceres Solver Report: Iterations: 58, Initial cost: 1.738313e+01, Final cost: 1.600415e+01, Termination: CONVERGENCE
# 2020-07-28 21:25:33,865 INFO: Removed outliers: 1
# 2020-07-28 21:25:33,872 INFO: -------------------------------------------------------
# 2020-07-28 21:25:33,893 INFO: 9.jpg resection inliers: 412 / 722
# 2020-07-28 21:25:33,911 DEBUG: Ceres Solver Report: Iterations: 5, Initial cost: 2.572439e+02, Final cost: 2.508510e+02, Termination: CONVERGENCE
# 2020-07-28 21:25:33,911 INFO: Adding 9.jpg to the reconstruction
# 2020-07-28 21:25:34,058 INFO: Re-triangulating
# 2020-07-28 21:25:35,830 DEBUG: Ceres Solver Report: Iterations: 101, Initial cost: 7.208190e+02, Final cost: 6.388514e+01, Termination: NO_CONVERGENCE
# 2020-07-28 21:25:37,774 DEBUG: Ceres Solver Report: Iterations: 93, Initial cost: 1.316900e+02, Final cost: 8.592449e+01, Termination: CONVERGENCE
# 2020-07-28 21:25:37,785 INFO: Removed outliers: 1
# 2020-07-28 21:25:37,792 INFO: -------------------------------------------------------
# 2020-07-28 21:25:37,797 INFO: 8.jpg resection inliers: 89 / 91
# 2020-07-28 21:25:37,801 DEBUG: Ceres Solver Report: Iterations: 5, Initial cost: 3.235476e+01, Final cost: 2.240510e+01, Termination: CONVERGENCE
# 2020-07-28 21:25:37,801 INFO: Adding 8.jpg to the reconstruction
# 2020-07-28 21:25:37,825 DEBUG: Local bundle sets: interior 4  boundary 0  other 0
# 2020-07-28 21:25:38,114 DEBUG: Ceres Solver Report: Iterations: 11, Initial cost: 1.117567e+02, Final cost: 9.654985e+01, Termination: NO_CONVERGENCE
# 2020-07-28 21:25:38,126 INFO: Removed outliers: 0
# 2020-07-28 21:25:38,132 INFO: -------------------------------------------------------
# 2020-07-28 21:25:38,372 INFO: Some images can not be added
# 2020-07-28 21:25:38,372 INFO: -------------------------------------------------------
# 2020-07-28 21:25:39,646 DEBUG: Ceres Solver Report: Iterations: 50, Initial cost: 9.945404e+01, Final cost: 9.431124e+01, Termination: CONVERGENCE
# 2020-07-28 21:25:39,658 INFO: Removed outliers: 0
# 2020-07-28 21:25:39,682 INFO: {'points_count': 2060, 'cameras_count': 4, 'observations_count': 4931, 'average_track_length': 2.3936893203883494, 'average_track_length_notwo': 3.067105263157895}
# 2020-07-28 21:25:39,682 INFO: Starting reconstruction with 13.jpg and 14.jpg
# 2020-07-28 21:25:39,702 INFO: Two-view reconstruction inliers: 749 / 749
# 2020-07-28 21:25:39,775 INFO: Triangulated: 544
# 2020-07-28 21:25:39,788 DEBUG: Ceres Solver Report: Iterations: 2, Initial cost: 5.712566e+05, Final cost: 5.712535e+05, Termination: CONVERGENCE
# 2020-07-28 21:25:39,901 DEBUG: Ceres Solver Report: Iterations: 2, Initial cost: 5.712542e+05, Final cost: 5.712532e+05, Termination: CONVERGENCE
# 2020-07-28 21:25:40,432 DEBUG: Ceres Solver Report: Iterations: 101, Initial cost: 2.403879e+01, Final cost: 1.383227e+01, Termination: NO_CONVERGENCE
# 2020-07-28 21:25
+01, Termination: NO_CONVERGENCE
# 2020-07-28 21:25:44,001 INFO: Removed outliers: 1
# 2020-07-28 21:25:44,059 INFO: -------------------------------------------------------
# 2020-07-28 21:25:44,066 INFO: 4.jpg resection inliers: 31 / 31
# 2020-07-28 21:25:44,069 DEBUG: Ceres Solver Report: Iterations: 11, Initial cost: 6.350119e+02, Final cost: 6.419709e+01, Termination: NO_CONVERGENCE
# 2020-07-28 21:25:44,069 INFO: Adding 4.jpg to the reconstruction
# 2020-07-28 21:25:44,154 INFO: Re-triangulating
# 2020-07-28 21:25:44,772 DEBUG: Ceres Solver Report: Iterations: 101, Initial cost: 1.934798e+02, Final cost: 4.988690e+01, Termination: NO_CONVERGENCE
# 2020-07-28 21:25:45,231 DEBUG: Ceres Solver Report: Iterations: 101, Initial cost: 4.341995e+01, Final cost: 3.795495e+01, Termination: NO_CONVERGENCE
# 2020-07-28 21:25:45,234 INFO: Removed outliers: 2
# 2020-07-28 21:25:45,239 INFO: -------------------------------------------------------
# 2020-07-28 21:25:45,468 INFO: Some images can not be added
# 2020-07-28 21:25:45,468 INFO: -------------------------------------------------------
# 2020-07-28 21:25:45,932 DEBUG: Ceres Solver Report: Iterations: 88, Initial cost: 4.072489e+01, Final cost: 3.572212e+01, Termination: CONVERGENCE
# 2020-07-28 21:25:45,935 INFO: Removed outliers: 0
# 2020-07-28 21:25:45,940 INFO: {'points_count': 414, 'cameras_count': 5, 'observations_count': 953, 'average_track_length': 2.3019323671497585, 'average_track_length_notwo': 6.647619047619048}
# 2020-07-28 21:25:45,940 INFO: Reconstruction 0: 5 images, 414 points
# 2020-07-28 21:25:45,940 INFO: Reconstruction 1: 4 images, 2060 points
# 2020-07-28 21:25:45,940 INFO: Reconstruction 2: 3 images, 460 points
# 2020-07-28 21:25:45,940 INFO: 3 partial reconstructions in total.

# %%
# !opensfm undistort mass/

# !opensfm compute_depthmaps mass/
# Out:
# 2020-07-28 21:26:25,049 DEBUG: Undistorting the reconstruction
# 2020-07-28 21:26:25,081 DEBUG: Undistorting image 0.jpg
# 2020-07-28 21:26:30,543 DEBUG: Undistorting image 1.jpg
# 2020-07-28 21:26:36,028 DEBUG: Undistorting image 2.jpg
# 2020-07-28 21:26:41,573 DEBUG: Undistorting image 3.jpg
# 2020-07-28 21:26:47,032 DEBUG: Undistorting image 4.jpg
# 2020-07-28 21:26:54,706 INFO: Computing neighbors
# 2020-07-28 21:26:54,737 INFO: Computing depthmap for image 0.jpg with PATCH_MATCH_SAMPLE
# 2020-07-28 21:27:14,337 INFO: Computing depthmap for image 1.jpg with PATCH_MATCH_SAMPLE
# 2020-07-28 21:27:39,077 INFO: Computing depthmap for image 2.jpg with PATCH_MATCH_SAMPLE
# 2020-07-28 21:28:03,815 INFO: Computing depthmap for image 3.jpg with PATCH_MATCH_SAMPLE
# 2020-07-28 21:28:29,293 INFO: Computing depthmap for image 4.jpg with PATCH_MATCH_SAMPLE
# 2020-07-28 21:28:52,985 INFO: Cleaning depthmap for image 0.jpg
# 2020-07-28 21:28:55,158 INFO: Cleaning depthmap for image 1.jpg
# 2020-07-28 21:28:57,721 INFO: Cleaning depthmap for image 2.jpg
# 2020-07-28 21:29:00,250 INFO: Cleaning depthmap for image 3.jpg
# 2020-07-28 21:29:02,849 INFO: Cleaning depthmap for image 4.jpg
# 2020-07-28 21:29:05,103 INFO: Pruning depthmap for image 0.jpg
# 2020-07-28 21:29:06,903 INFO: Pruning depthmap for image 1.jpg
# 2020-07-28 21:29:10,661 INFO: Pruning depthmap for image 2.jpg
# 2020-07-28 21:29:14,415 INFO: Pruning depthmap for image 3.jpg
# 2020-07-28 21:29:18,227 INFO: Pruning depthmap for image 4.jpg
# 2020-07-28 21:29:20,905 INFO: Merging depthmaps

# %%
# Origin of our reconstruction, as given by the reference_lla.json (made from the reconstruction)
with open("mass/reference_lla.json", "r") as f:
    reference_lla = json.load(f)
    latitude=reference_lla["latitude"]
    longitude=reference_lla["longitude"]
    altitude=reference_lla["altitude"]

# This is the json file that contains the reconstructed feature points
with open("mass/reconstruction.json", "r") as f:
    reconstructions = json.load(f)

# %%
try:
    from pymap3d import enu2geodetic
except:
    # !pip install pymap3d
    from pymap3d import enu2geodetic
from opensfm.features import denormalized_image_coordinates

# reading the csv
tracks = pd.read_csv("mass/tracks.csv", sep="\t", skiprows=1, names=["image_name", "track_id", "feature_id", "x", "y", "s", "R", "G", "B"])

# we need to denormalize the coordinates to turn them into regular pixel coordinates
normalized_coor = tracks[["x", "y", "s"]]
denormalized_coor = denormalized_image_coordinates(normalized_coor.values, 4496, 3000)

# create a new column with the denormalized coordinates
tracks["denorm_x"] = denormalized_coor[:, 0]
tracks["denorm_y"] = denormalized_coor[:, 1]

# %%
from shapely.geometry import Polygon
import geopandas as gpd

img_name_list = []
poly_list = []

for reconst in reconstructions:
    for shot in reconst["shots"]:
        # some housekeeping
        shot_name = shot.split(".")[0]
        img = cv2.imread("mass/images/"+shot) 
        h,w,_ = img.shape
        
        # here we get the features from the image and their corresponding reconstructed features
        reconst_ids = list(map(int, reconst["points"].keys()))
        tracks_shot = tracks[(tracks["image_name"] == shot) & (tracks["track_id"].isin(reconst_ids))]
        
        normalized_coor = tracks_shot[["x", "y", "s"]]
        denormalized_coor = denormalized_image_coordinates(normalized_coor.values, w, h)
        
        tracks_shot["denorm_x"] = denormalized_coor[:, 0]
        tracks_shot["denorm_y"] = denormalized_coor[:, 1]
        
        denorm_shot = np.round(tracks_shot[["denorm_x", "denorm_y"]].values)
        reconst_shot = np.array([reconst["points"][str(point)]["coordinates"] for point in tracks_shot["track_id"]])
        
        # transformation for the new orthorectified image
        H, inliers = cv2.findHomography(denorm_shot, reconst_shot[:, :2],cv2.RANSAC,5.0)
        
        
        pts = np.float32([ [0,0],[0,h-1],[w-1,h-1],[w-1,0] ]).reshape(-1,1,2)
        dst = cv2.perspectiveTransform(pts,H)[:,0,:]
        print(dst)
                
        geo_shot = np.array([enu2geodetic(dst[i, 0],dst[i, 1],0,latitude,longitude,altitude) for i in range(dst.shape[0])])  
        
        poly_points_list = geo_shot[:, :2].tolist()
        poly_points_tuples = tuple(map(tuple, poly_points_list))
        print(poly_points_tuples)
        
        img_name_list.append(shot_name)
        poly_list.append(Polygon(poly_points))

used_images = gpd.GeoDataFrame({'image_name':img_name_list, 'geometry':poly_list}, crs='EPSG:4326')
used_images
# Out:
# [[  1698.0835 -16773.39  ]
#  [  9882.963  -14351.711 ]
#  [  9828.843  -13929.247 ]
#  [  2781.1558 -12240.3125]]
# ((42.056900885575324, -70.73361246258916), (42.07864272332257, -70.63469323029294), (42.082446791232115, -70.63534014559883), (42.09770862605715, -70.72050669106746))
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-b9bc01a47e37> in <module>
#      40
#      41         img_name_list.append(shot_name)
# ---> 42         poly_list.append(Polygon(poly_points))
#      43
#      44 used_images = gpd.GeoDataFrame({'image_name':img_name_list, 'geometry':poly_list}, crs='EPSG:4326')
#
# NameError: name 'poly_points' is not defined

# %%
tracks_shot['geometry'] = Polygon
tracks_shot
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       image_name  track_id  feature_id         x         y         s    R  \
# 65425     12.jpg     10178         944 -0.097210  0.066295  0.001949   47
# 65426     12.jpg     10174        1860 -0.078433  0.085991  0.002253   45
# 65429     12.jpg     10170         223  0.001737  0.051213  0.001803   67
# 65430     12.jpg     10169        4202 -0.138079 -0.067357  0.004781   33
# 65432     12.jpg     10163        4647 -0.217622  0.070484  0.008360   19
# ...          ...       ...         ...       ...       ...       ...  ...
# 65741     12.jpg      7666        1931  0.094931  0.079784  0.002284  145
# 65742     12.jpg     10036         795 -0.053459  0.070149  0.001921   61
# 65744     12.jpg     10042        4692 -0.115954 -0.050439  0.009405  159
# 65745     12.jpg     10086        1707 -0.154600  0.084015  0.002174   40
# 65746     12.jpg      9966         163 -0.004589 -0.040654  0.001787   37
#
#          G    B    denorm_x   denorm_y  \
# 65425   55   57  2416.23760  2397.2706
# 65426   24   19  2528.90080  2515.4490
# 65429   65   71  3009.92488  2306.7798
# 65430   35   38  2171.02600  1595.3574
# 65432   21   23  1693.76800  2422.4028
# ...    ...  ...         ...        ...
# 65741  156  151  3569.08480  2478.2016
# 65742   66   70  2678.74840  2420.3964
# 65744  160  154  2303.77600  1696.8666
# 65745   26   27  2071.90000  2503.5906
# 65746   35   31  2971.96822  1755.5778
#
#                                          geometry
# 65425  <class 'shapely.geometry.polygon.Polygon'>
# 65426  <class 'shapely.geometry.polygon.Polygon'>
# 65429  <class 'shapely.geometry.polygon.Polygon'>
# 65430  <class 'shapely.geometry.polygon.Polygon'>
# 65432  <class 'shapely.geometry.polygon.Polygon'>
# ...                                           ...
# 65741  <class 'shapely.geometry.polygon.Polygon'>
# 65742  <class 'shapely.geometry.polygon.Polygon'>
# 65744  <class 'shapely.geometry.polygon.Polygon'>
# 65745  <class 'shapely.geometry.polygon.Polygon'>
# 65746  <class 'shapely.geometry.polygon.Polygon'>
#
# [145 rows x 12 columns]

# %%
import contextily as ctx
# used_images = used_images.to_crs(epsg=3857)
# ax = used_images.plot(figsize=(10, 10), alpha=0.5, edgecolor='k')
# ctx.add_basemap(ax)

ax = used_images.to_crs(epsg=3857).plot(column='geometry', figsize=(100,100), alpha=0.6, cmap='binary')
ctx.add_basemap(ax url=getattr(ctx.sources,'ST_TONER_LITE'))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/contextily/tile.py in _retryer(tile_url, wait, max_retries)
#     443         request = requests.get(tile_url, headers={"user-agent": USER_AGENT})
# --> 444         request.raise_for_status()
#     445     except requests.HTTPError:
#
# /opt/conda/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     940         if http_error_msg:
# --> 941             raise HTTPError(http_error_msg, response=self)
#     942
#
# HTTPError: 404 Client Error: Not Found for url: https://stamen-tiles-a.a.ssl.fastly.net/terrain/16/40429/51202.png
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-65-97d3e9ae84ed> in <module>
#       5
#       6 ax = used_images.to_crs(epsg=3857).plot(figsize=(100,100), alpha=0.6, cmap='binary')
# ----> 7 ctx.add_basemap(ax)
#
# /opt/conda/lib/python3.7/site-packages/contextily/plotting.py in add_basemap(ax, zoom, source, interpolation, attribution, attribution_size, reset_extent, crs, resampling, url, **extra_imshow_args)
#     142         # Download image
#     143         image, extent = bounds2img(
# --> 144             left, bottom, right, top, zoom=zoom, source=source, ll=False
#     145         )
#     146         # Warping
#
# /opt/conda/lib/python3.7/site-packages/contextily/tile.py in bounds2img(w, s, e, n, zoom, source, ll, wait, max_retries, url)
#     246         x, y, z = t.x, t.y, t.z
#     247         tile_url = _construct_tile_url(provider, x, y, z)
# --> 248         image = _fetch_tile(tile_url, wait, max_retries)
#     249         tiles.append(t)
#     250         arrays.append(image)
#
# /opt/conda/lib/python3.7/site-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     563
#     564     def __call__(self, *args, **kwargs):
# --> 565         return self._cached_call(args, kwargs)[0]
#     566
#     567     def __getstate__(self):
#
# /opt/conda/lib/python3.7/site-packages/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     529
#     530         if must_call:
# --> 531             out, metadata = self.call(*args, **kwargs)
#     532             if self.mmap_mode is not None:
#     533                 # Memmap the output at the first call to be consistent with
#
# /opt/conda/lib/python3.7/site-packages/joblib/memory.py in call(self, *args, **kwargs)
#     725         if self._verbose > 0:
#     726             print(format_call(self.func, args, kwargs))
# --> 727         output = self.func(*args, **kwargs)
#     728         self.store_backend.dump_item(
#     729             [func_id, args_id], output, verbose=self._verbose)
#
# /opt/conda/lib/python3.7/site-packages/contextily/tile.py in _fetch_tile(tile_url, wait, max_retries)
#     301 @memory.cache
#     302 def _fetch_tile(tile_url, wait, max_retries):
# --> 303     request = _retryer(tile_url, wait, max_retries)
#     304     with io.BytesIO(request.content) as image_stream:
#     305         image = Image.open(image_stream).convert("RGB")
#
# /opt/conda/lib/python3.7/site-packages/contextily/tile.py in _retryer(tile_url, wait, max_retries)
#     447             raise requests.HTTPError(
#     448                 "Tile URL resulted in a 404 error. "
# --> 449                 "Double-check your tile url:\n{}".format(tile_url)
#     450             )
#     451         elif request.status_code == 104:
#
# HTTPError: Tile URL resulted in a 404 error. Double-check your tile url:
# https://stamen-tiles-a.a.ssl.fastly.net/terrain/16/40429/51202.png

# %%
import open3d as o3d
from open3d import JVisualizer

pcd = o3d.io.read_point_cloud("mass/reconstruction.ply")
visualizer = JVisualizer()
visualizer.add_geometry(pcd)
visualizer.show()
# Out:
# JVisualizer with 1 geometries
